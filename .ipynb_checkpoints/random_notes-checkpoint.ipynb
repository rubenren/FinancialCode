# %% [markdown]
# Although my initial study was pretty decent, I would like some more recent verificatiion, maybe even try and throw these models at the pandemic period.

# %%
# Imports

import pandas as pd
import numpy as np
import datetime
import yfinance as yf

from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl import config_tickers


from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR
from finrl.main import check_and_make_directories
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv

check_and_make_directories([TRAINED_MODEL_DIR])

import itertools

# %%
# Step 1 is to set the correct range for the data you want it to process
TRAIN_START = '2009-01-01'
TRAIN_END = '2021-07-01'
TEST_START = '2021-07-01'
TEST_END = '2023-05-01'

# Grabbing the dasta from yahoo finance
df_raw = YahooDownloader(start_date=TRAIN_START,
                         end_date=TEST_END,
                         ticker_list=config_tickers.DOW_30_TICKER
                        ).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (105581, 8)

# %%
df_raw
# Out:
#               date        open        high  ...     volume   tic  day
# 0       2009-01-02    3.067143    3.251429  ...  746015200  AAPL    4
# 1       2009-01-02   58.590000   59.080002  ...    6547900  AMGN    4
# 2       2009-01-02   18.570000   19.520000  ...   10955700   AXP    4
# 3       2009-01-02   42.799999   45.560001  ...    7010200    BA    4
# 4       2009-01-02   44.910000   46.980000  ...    7117200   CAT    4
# ...            ...         ...         ...  ...        ...   ...  ...
# 105576  2023-04-28  488.690002  493.959991  ...    2398400   UNH    4
# 105577  2023-04-28  228.649994  233.570007  ...   11627900     V    4
# 105578  2023-04-28   38.560001   39.000000  ...   19194400    VZ    4
# 105579  2023-04-28   35.139999   35.380001  ...   11878500   WBA    4
# 105580  2023-04-28  151.289993  152.169998  ...    4693900   WMT    4
#
# [105581 rows x 8 columns]

# %% [markdown]
# These will be the technical indicators we use for our machine

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
# Next we do some data prep, using built-ins of course
fe = FeatureEngineer(
    use_technical_indicator=True,
    tech_indicator_list=INDICATORS,
    use_vix=True,
    use_turbulence=True,
    user_defined_feature=False
)

df_processed = fe.preprocess_data(df_raw)
df_processed.head()
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3604, 8)
# Successfully added vix
# Successfully added turbulence index
#          date       open       high  ...  close_60_sma        vix  turbulence
# 0  2009-01-02   3.067143   3.251429  ...      2.754725  39.189999         0.0
# 1  2009-01-02  58.590000  59.080002  ...     43.422932  39.189999         0.0
# 2  2009-01-02  18.570000  19.520000  ...     15.308598  39.189999         0.0
# 3  2009-01-02  42.799999  45.560001  ...     33.941090  39.189999         0.0
# 4  2009-01-02  44.910000  46.980000  ...     31.408859  39.189999         0.0
#
# [5 rows x 18 columns]

# %%
# Now for the boilerplate code talked about in the intial study
list_ticker = df_processed['tic'].unique().tolist()
list_date = list(pd.date_range(df_processed['date'].min(), df_processed['date'].max()).astype(str))
combination = list(itertools.product(list_date, list_ticker))

# %%
processed_full = pd.DataFrame(combination, columns=["date", "tic"]).merge(df_processed, on=["date","tic"], how="left")
processed_full = processed_full[processed_full['date'].isin(df_processed['date'])]
processed_full = processed_full.sort_values(['date', 'tic'])
processed_full = processed_full.fillna(0)
processed_full
# Out:
#               date   tic        open  ...  close_60_sma        vix  turbulence
# 0       2009-01-02  AAPL    3.067143  ...      2.754725  39.189999    0.000000
# 1       2009-01-02  AMGN   58.590000  ...     43.422932  39.189999    0.000000
# 2       2009-01-02   AXP   18.570000  ...     15.308598  39.189999    0.000000
# 3       2009-01-02    BA   42.799999  ...     33.941090  39.189999    0.000000
# 4       2009-01-02   CAT   44.910000  ...     31.408859  39.189999    0.000000
# ...            ...   ...         ...  ...           ...        ...         ...
# 151636  2023-04-27   UNH  482.200012  ...    484.629329  17.030001   48.223586
# 151637  2023-04-27     V  228.669998  ...    224.769116  17.030001   48.223586
# 151638  2023-04-27    VZ   37.200001  ...     38.252595  17.030001   48.223586
# 151639  2023-04-27   WBA   34.860001  ...     34.571471  17.030001   48.223586
# 151640  2023-04-27   WMT  150.779999  ...    143.551109  17.030001   48.223586
#
# [104516 rows x 18 columns]

# %%
# Perfect, now we split our data into train and test
df_train = data_split(processed_full, TRAIN_START, TRAIN_END)
df_test = data_split(processed_full, TEST_START, TEST_END)

print(len(df_train))
print(len(df_test))
# Out:
# 91205
# 13311

# %%
# Alright, now we just need to load our models and run the evals, since the td3 performed the best we will use that one
# first we set up our environment
stock_dim = len(df_train.tic.unique())
state_space = 1 + 2 * stock_dim + len(INDICATORS) * stock_dim
print(f"Stock Dimension: {stock_dim}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dim # The cost of purchasing
num_stock_shares = [0] * stock_dim # Initial stock allocation (ie. we start with owning only cash)

env_kwargs = {
    'hmax': 100, # Number of shares allowed to buy or sell at any given step
    'initial_amount': 1_000,
    'num_stock_shares': num_stock_shares,
    'buy_cost_pct': buy_cost_list,
    'sell_cost_pct': sell_cost_list,
    'state_space': state_space,
    'stock_dim': stock_dim,
    'tech_indicator_list': INDICATORS,
    'action_space': stock_dim,
    'reward_scaling': 1e-4
}

e_test_gym = StockTradingEnv(
    df = df_test,
    turbulence_threshold=70,
    risk_indicator_col='vix',
    **env_kwargs
)

# %%
# Now that we have set up our environment, we now load our model and test it
from stable_baselines3 import TD3

trained_td3 = TD3.load(TRAINED_MODEL_DIR + "/agent_td3")

# %%
df_acc_val_td3, df_actions_td3 = DRLAgent.DRL_prediction(
    model=trained_td3,
    environment=e_test_gym
)
# Out:
# hit end!

# %%
df_acc_val_td3 = df_acc_val_td3.set_index('date')
df_acc_val_td3.columns=['TD3']

# %%
from plotnine import *

# %%
df_results_plot = df_acc_val_td3.reset_index().melt(id_vars='date')

# Drawing the plot
p = ggplot(df_acc_val_td3, aes(x='date', y='value', color='variable'))
p + geom_line() + theme_classic() + theme(axis_text_x=element_text(rotation=90), aspect_ratio=0.4, figure_size=(10, 5))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/plotnine/mapping/evaluation.py:225, in evaluate(aesthetics, data, env)
#     224 try:
# --> 225     new_val = env.eval(col, inner_namespace=data)
#     226 except Exception as e:
#
# File ~/.local/lib/python3.10/site-packages/patsy/eval.py:169, in EvalEnvironment.eval(self, expr, source_name, inner_namespace)
#     168 code = compile(expr, source_name, "eval", self.flags, False)
# --> 169 return eval(code, {}, VarLookupDict([inner_namespace]
#     170                                     + self._namespaces))
#
# File <string>:1
#
# NameError: name 'date' is not defined
#
# During handling of the above exception, another exception occurred:
#
# PlotnineError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/IPython/core/formatters.py:708, in PlainTextFormatter.__call__(self, obj)
#     701 stream = StringIO()
#     702 printer = pretty.RepresentationPrinter(stream, self.verbose,
#     703     self.max_width, self.newline,
#     704     max_seq_length=self.max_seq_length,
#     705     singleton_pprinters=self.singleton_printers,
#     706     type_pprinters=self.type_printers,
#     707     deferred_pprinters=self.deferred_printers)
# --> 708 printer.pretty(obj)
#     709 printer.flush()
#     710 return stream.getvalue()
#
# File ~/.local/lib/python3.10/site-packages/IPython/lib/pretty.py:410, in RepresentationPrinter.pretty(self, obj)
#     407                         return meth(obj, self, cycle)
#     408                 if cls is not object \
#     409                         and callable(cls.__dict__.get('__repr__')):
# --> 410                     return _repr_pprint(obj, self, cycle)
#     412     return _default_pprint(obj, self, cycle)
#     413 finally:
#
# File ~/.local/lib/python3.10/site-packages/IPython/lib/pretty.py:778, in _repr_pprint(obj, p, cycle)
#     776 """A pprint that just redirects to the normal repr function."""
#     777 # Find newlines and replace them with p.break_()
# --> 778 output = repr(obj)
#     779 lines = output.splitlines()
#     780 with p.group():
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:114, in ggplot.__repr__(self)
#     110 def __repr__(self) -> str:
#     111     """
#     112     Print/show the plot
#     113     """
# --> 114     figure = self.draw(show=True)
#     116     dpi = figure.get_dpi()
#     117     W = int(figure.get_figwidth() * dpi)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:224, in ggplot.draw(self, show)
#     222 self = deepcopy(self)
#     223 with plot_context(self, show=show):
# --> 224     self._build()
#     226     # setup
#     227     figure, axs = self._create_figure()
#
# File ~/.local/lib/python3.10/site-packages/plotnine/ggplot.py:314, in ggplot._build(self)
#     310 layout.setup(layers, self)
#     312 # Compute aesthetics to produce data with generalised
#     313 # variable names
# --> 314 layers.compute_aesthetics(self)
#     316 # Transform data using all scales
#     317 layers.transform(scales)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/layer.py:467, in Layers.compute_aesthetics(self, plot)
#     465 def compute_aesthetics(self, plot: Ggplot):
#     466     for l in self:
# --> 467         l.compute_aesthetics(plot)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/layer.py:260, in layer.compute_aesthetics(self, plot)
#     253 def compute_aesthetics(self, plot: Ggplot):
#     254     """
#     255     Return a dataframe where the columns match the aesthetic mappings
#     256
#     257     Transformations like 'factor(cyl)' and other
#     258     expression evaluation are  made in here
#     259     """
# --> 260     evaled = evaluate(self.mapping._starting, self.data, plot.environment)
#     261     evaled_aes = aes(**{str(col): col for col in evaled})
#     262     plot.scales.add_defaults(evaled, evaled_aes)
#
# File ~/.local/lib/python3.10/site-packages/plotnine/mapping/evaluation.py:227, in evaluate(aesthetics, data, env)
#     225     new_val = env.eval(col, inner_namespace=data)
#     226 except Exception as e:
# --> 227     raise PlotnineError(_TPL_EVAL_FAIL.format(ae, col, str(e)))
#     229 try:
#     230     evaled[ae] = new_val
#
# PlotnineError: "Could not evaluate the 'x' mapping: 'date' (original error: name 'date' is not defined)"
